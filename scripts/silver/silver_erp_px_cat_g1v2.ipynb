# %%
df = spark.read.format("delta").table("workspace.bronze.erp_px_cat_g1v2")

# %%
from pyspark.sql.functions import col, regexp_replace

df = df.withColumn("id", regexp_replace(col("id"), "_", "-"))

# %%
df.write.mode("overwrite").saveAsTable("silver.erp_px_cat_g1v2")

# %%
display (df)
